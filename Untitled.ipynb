# %%
from networkx import binomial_tree,complete_graph,cycle_graph,random_regular_graph,path_graph,grid_graph,barbell_graph,ladder_graph# as tree,complete,cycle,regular4,path,grid,barbell,ladder
import itertools as it
from functools import reduce
import pickle
import pandas as pd
import torch
import numpy as np
import random

# %%
from scipy.stats import spearmanr,pearsonr
from sklearn.metrics import r2_score
def train(model,optimizer,train_graphs,y_true,device):
    model.train()   
    total_loss = 0

    for i,data  in enumerate(train_graphs):
        optimizer.zero_grad()
        out = model.inference(data,training=True)
        #print(out,y_true[i])
        loss = model.loss(out, torch.tensor([y_true[i]]))
        loss.backward()
        total_loss+=loss
        optimizer.step()
    return total_loss/len(train_graphs)
    
def test(model,test_graphs,y_true):
    model.eval()   
    spearman = 0
    pearson=0
    mape=0
    mae=0
    r2=0
    
    y_pred = []
    
    for data in test_graphs:
        out = model.inference(data,training=False)
        y_pred+=(out.flatten().to('cpu').tolist())
        
    li = abs((torch.tensor(y_true)-torch.tensor(y_pred))/torch.tensor(y_true)).tolist()
    mape += np.mean(li)
    r2 += r2_score(y_true,y_pred)
    spearman += spearmanr(y_true,y_pred).correlation
    pearson += pearsonr(y_true,y_pred)[0]

    mae += F.l1_loss(torch.tensor(y_pred), torch.tensor(y_true))

    return mae,mape,r2,pearson,spearman

# %%
all_structures = [binomial_tree,complete_graph, cycle_graph, random_regular_graph, path_graph, ladder_graph]
all_datasets = []
q=0

import matplotlib.pyplot as plt

results = pd.DataFrame(columns=['train structures','test structures','train mae ','train mape','train r2','train pearson','train spearman','test mae ','test mape','test r2','test pearson','test spearman'])

#results.to_csv('results_naive.csv')

for i in range(1,len(all_structures)):
    train_structures=list(it.combinations(all_structures,i))
    #print(list(train_structures))
    for train_structs in train_structures:
        train_data = []
        name_tr = ''
        
        for struct in train_structs:
            name_tr += struct.__name__.split('_')[0] +'_'
            with open('datasets/'+struct.__name__.split('_')[0]+'_train'+'.pickle','rb') as f:
                app = pickle.load(f)
                train_data += app
        
        train_data = random.sample(train_data,500)
        
        name_tr = name_tr[:-1]
        y = list(map( lambda x: x.y, train_data))
        model = IRM(num_layers=2,num_features=train_data[0].x.shape[1],y=y,hidden_layer=32,conv='GAT',task='regression',dropout=0.3) #TODO
        optimizer = torch.optim.Adam(model.parameters(), lr=0.005,weight_decay = 1e-5)
        device = torch.device('cuda') 
        losses=[]
        for epoch in range(30):
            loss=train(model,optimizer,train_data,y,device)
            losses.append(float(loss))
            #print('epoch:{}, loss: {}'.format(epoch,loss))#, test accuracies: mae: {}, mape: {}, r2:{}, spearman:{}, pearson: {}'.format(epoch,loss,scores[0],scores[1],scores[2],scores[3],scores[4]))
        plt.plot(losses)
        plt.title('loss')
        plt.show()
        train_acc=test(model, train_data, y)#TODO
        
        residuals = list(set(all_structures) - set(train_structs))
        for j in range(1,len(residuals)+1):        
            test_structures = list(it.combinations(residuals,j))
            for test_structs in test_structures:
                test_data = []
                name_te= ''
                for test_struct in test_structs:
                    name_te+=test_struct.__name__.split('_')[0]+'_'
                    with open('datasets/'+test_struct.__name__.split('_')[0]+'_test'+'.pickle','rb') as f:
                            app=pickle.load(f)
                            test_data+=app
               # name_te = name_te[:-1]
                test_data = random.sample(test_data,250) 
                y_te = list(map( lambda x: x.y, test_data))
                test_acc = test(model, test_data, y_te)#TODO
                to_append =[name_tr,name_te, float(train_acc[0]),train_acc[1],train_acc[2],train_acc[3],train_acc[4],float(test_acc[0]),test_acc[1],test_acc[2],test_acc[3],test_acc[4]]
                            #print(to_append)
                row_series = pd.Series(to_append, index = results.columns)
                results = results.append(row_series, ignore_index = True)
                results.head()

                results.to_csv('results_naive.csv')

# %%
results_groupby_train = results.groupby('train structures').min()
results_groupby_test = results.groupby('test structures').min()
#results_groupby_test[results_groupby_test['test mape']== min(results_groupby_test['test mape'])]
results_groupby_test
# Out:
#                               train structures    train mae   train mape  \
# test structures
# binomial_                             complete   1004.755510    0.163231
# binomial_complete_                       cycle   1004.755510    0.163231
# binomial_complete_cycle_           path_ladder   1922.824036    0.211494
# binomial_cycle_                       complete   1004.755510    0.165431
# binomial_cycle_complete_                ladder   1004.755510    0.165431
# ...                                        ...           ...         ...
# random_ladder_path_cycle_    binomial_complete  50837.318332    1.783786
# random_path_                          binomial   1196.288936    0.175928
# random_path_complete_                 binomial   1196.288936    0.175928
# random_path_complete_cycle_    binomial_ladder   2387.818844    0.217388
# random_path_cycle_           binomial_complete   2387.818844    0.217388
#
#                              train r2  train pearson  train spearman  \
# test structures
# binomial_                   -3.119361      -0.043139       -0.190049
# binomial_complete_           0.032363       0.660302        0.655214
# binomial_complete_cycle_     0.629858       0.806062        0.818999
# binomial_cycle_             -3.119361      -0.043139       -0.190049
# binomial_cycle_complete_     0.032363       0.660302        0.655214
# ...                               ...            ...             ...
# random_ladder_path_cycle_   -1.548133       0.239398        0.202910
# random_path_                -3.119361       0.239398        0.202910
# random_path_complete_        0.032363       0.660302        0.655214
# random_path_complete_cycle_  0.730968       0.898162        0.915001
# random_path_cycle_          -3.119361       0.239398        0.202910
#
#                                  test mae   test mape     test r2  \
# test structures
# binomial_                      4174.836101   0.223433 -424.419685
# binomial_complete_           319563.680526   0.576128   -0.808904
# binomial_complete_cycle_     228483.502938   0.512898   -0.374485
# binomial_cycle_                4446.841636   0.215910 -551.723330
# binomial_cycle_complete_     202056.946508   0.480851   -0.371756
# ...                                    ...        ...         ...
# random_ladder_path_cycle_     46637.715756   1.654639   -6.736024
# random_path_                   8256.404958   0.272126 -123.350390
# random_path_complete_        225184.829888   0.492994   -0.502729
# random_path_complete_cycle_  167992.881830   0.443979   -0.283718
# random_path_cycle_             6535.783542   0.277798  -20.251673
#
#                              test pearson  test spearman
# test structures
# binomial_                       -0.607166      -0.387802
# binomial_complete_               0.021188       0.073573
# binomial_complete_cycle_         0.419089       0.547268
# binomial_cycle_                 -0.615222      -0.530007
# binomial_cycle_complete_         0.179215       0.296754
# ...                                   ...            ...
# random_ladder_path_cycle_        0.201797       0.257268
# random_path_                     0.264806       0.291744
# random_path_complete_           -0.109806       0.020853
# random_path_complete_cycle_      0.319703       0.434079
# random_path_cycle_               0.379702       0.277187
#
# [108 rows x 11 columns]

# %%
from torch_geometric.nn import GCNConv, SAGEConv,GATConv, SGConv, ChebConv 
import collections 
import torch.nn.functional as F
import torch

class IRM(torch.nn.Module):
    def __init__(self,num_layers,num_features,y,hidden_layer,conv='GCN',task='regression',dropout=0.2):
        super().__init__()
        self.dropout=dropout
        self.task=task
        self.num_layers = num_layers        
        self.convs = torch.nn.ModuleList()
        self.num_features = num_features
        if task == 'classification':
            self.out_channels = len(collections.Counter(y))
        else:
            self.out_channels = 24
        self.hidden_layer = hidden_layer
        self.conv=conv
        
        if self.conv == 'GCN':
            if self.num_layers == 1:
                self.convs.append(GCNConv(self.num_features,  self.out_channels))
                if task=='regression':
                    self.convs.append(torch.nn.Linear(self.out_channels,1))
                    
            else:
                self.convs.append(GCNConv(self.num_features, self.hidden_layer))
                for i in range(1,self.num_layers-1):
                    self.convs.append(GCNConv(self.hidden_layer, self.hidden_layer))
                self.convs.append(GCNConv(self.hidden_layer,  self.out_channels)) 
                if task=='regression':
                    self.convs.append(torch.nn.Linear(self.out_channels,1))
                    
        elif self.conv == 'SAGE':
            if self.num_layers == 1:
                self.convs.append(SAGEConv(self.num_features,  self.out_channels))
                if task=='regression':
                    self.convs.append(torch.nn.Linear(self.out_channels,1))
                    
            else:
                self.convs.append(SAGEConv(self.num_features, self.hidden_layer))
                for i in range(1,self.num_layers-1):
                    self.convs.append(SAGEConv(self.hidden_layer, self.hidden_layer))
                self.convs.append(SAGEConv(self.hidden_layer,  self.out_channels))   
                if task=='regression':
                    self.convs.append(torch.nn.Linear(self.out_channels,1))
                    
        elif self.conv == 'GAT':
            if self.num_layers == 1:
                self.convs.append(GATConv(self.num_features,  self.out_channels))
                if task=='regression':
                    self.convs.append(torch.nn.Linear(self.out_channels,1))
                    
            else: 
                self.convs.append(GATConv(self.num_features, self.hidden_layer))
                for i in range(1,self.num_layers-1):
                    self.convs.append(GATConv(self.hidden_layer, self.hidden_layer))
                self.convs.append(GATConv(self.hidden_layer,  self.out_channels))
                
                if task=='regression':
                    self.convs.append(torch.nn.Linear(self.out_channels,1))
                    
    def forward(self,x,adjs,training):
        for i, (edge_index, _, size) in enumerate(adjs):
            x_target = x[:size[1]]  # Target nodes are always placed first.
            x = self.convs[i]((x,x_target), edge_index)
            if i != self.num_layers - 1:
                x = F.relu(x)
                x = F.dropout(x, p=self.dropout, training=training)
        if self.task == 'regression':
            x = self.convs[len(self.convs)-1](x)
            return x 
        else:
            return x.log_softmax(dim=1)
        
    def inference(self,data,training): 
        
        x, edge_index, edge_weight = data.x, data.edge_index, data.edge_attr
       
        for i in range(self.num_layers):
            x = self.convs[i](x, edge_index)
            if i != self.num_layers - 1:
                x = x.relu()
                x = F.dropout(x, p=self.dropout, training=training)
        
        if self.task == 'regression':
            
            x = self.convs[len(self.convs)-1](x)
            
            return sum(x) 
        else:
            return x.log_softmax(dim=1)
           
    def loss(self, pred, label):
        #print(lmbda*((torch.norm(pred))*(torch.norm(pred))))
        return F.l1_loss(pred, label) #+ lmbda*((torch.norm(pred))*(torch.norm(pred)))

# %%
import argparse
import numpy as np
import torch
from torchvision import datasets
from torch import nn, optim, autograd

parser = argparse.ArgumentParser(description='Colored MNIST')
parser.add_argument('--hidden_dim', type=int, default=256)
parser.add_argument('--l2_regularizer_weight', type=float,default=0.001)
parser.add_argument('--lr', type=float, default=0.001)
parser.add_argument('--n_restarts', type=int, default=10)
parser.add_argument('--penalty_anneal_iters', type=int, default=100)
parser.add_argument('--penalty_weight', type=float, default=10000.0)
parser.add_argument('--steps', type=int, default=501)
parser.add_argument('--grayscale_model', action='store_true')
flags = parser.parse_args()

print('Flags:')
for k,v in sorted(vars(flags).items()):
  print("\t{}: {}".format(k, v))

final_train_accs = []
final_test_accs = []

for restart in range(flags.n_restarts):
  print("Restart", restart)

  # Load MNIST, make train/val splits, and shuffle train set examples

  mnist = datasets.MNIST('~/datasets/mnist', train=True, download=True)
  mnist_train = (mnist.data[:50000], mnist.targets[:50000])
  mnist_val = (mnist.data[50000:], mnist.targets[50000:])

  rng_state = np.random.get_state()
  np.random.shuffle(mnist_train[0].numpy())
  np.random.set_state(rng_state)
  np.random.shuffle(mnist_train[1].numpy())

  # Build environments

  def make_environment(images, labels, e):
    def torch_bernoulli(p, size):
      return (torch.rand(size) < p).float()
    def torch_xor(a, b):
      return (a-b).abs() # Assumes both inputs are either 0 or 1
    # 2x subsample for computational convenience
    images = images.reshape((-1, 28, 28))[:, ::2, ::2]
    # Assign a binary label based on the digit; flip label with probability 0.25
    labels = (labels < 5).float()
    labels = torch_xor(labels, torch_bernoulli(0.25, len(labels)))
    # Assign a color based on the label; flip the color with probability e
    colors = torch_xor(labels, torch_bernoulli(e, len(labels)))
    # Apply the color to the image by zeroing out the other color channel
    images = torch.stack([images, images], dim=1)
    images[torch.tensor(range(len(images))), (1-colors).long(), :, :] *= 0
    return {
      'images': (images.float() / 255.).cuda(),
      'labels': labels[:, None].cuda()
    }

  envs = [
    make_environment(mnist_train[0][::2], mnist_train[1][::2], 0.2),
    make_environment(mnist_train[0][1::2], mnist_train[1][1::2], 0.1),
    make_environment(mnist_val[0], mnist_val[1], 0.9)
  ]

  # Define and instantiate the model

  class MLP(nn.Module):
    def __init__(self):
      super(MLP, self).__init__()
      if flags.grayscale_model:
        lin1 = nn.Linear(14 * 14, flags.hidden_dim)
      else:
        lin1 = nn.Linear(2 * 14 * 14, flags.hidden_dim)
      lin2 = nn.Linear(flags.hidden_dim, flags.hidden_dim)
      lin3 = nn.Linear(flags.hidden_dim, 1)
      for lin in [lin1, lin2, lin3]:
        nn.init.xavier_uniform_(lin.weight)
        nn.init.zeros_(lin.bias)
      self._main = nn.Sequential(lin1, nn.ReLU(True), lin2, nn.ReLU(True), lin3)
    def forward(self, input):
      if flags.grayscale_model:
        out = input.view(input.shape[0], 2, 14 * 14).sum(dim=1)
      else:
        out = input.view(input.shape[0], 2 * 14 * 14)
      out = self._main(out)
      return out

  mlp = MLP().cuda()

  # Define loss function helpers

  def mean_nll(logits, y):
    return nn.functional.binary_cross_entropy_with_logits(logits, y)

  def mean_accuracy(logits, y):
    preds = (logits > 0.).float()
    return ((preds - y).abs() < 1e-2).float().mean()

  def penalty(logits, y):
    scale = torch.tensor(1.).cuda().requires_grad_()
    loss = mean_nll(logits * scale, y)
    grad = autograd.grad(loss, [scale], create_graph=True)[0]
    return torch.sum(grad**2)

  # Train loop

  def pretty_print(*values):
    col_width = 13
    def format_val(v):
      if not isinstance(v, str):
        v = np.array2string(v, precision=5, floatmode='fixed')
      return v.ljust(col_width)
    str_values = [format_val(v) for v in values]
    print("   ".join(str_values))

  optimizer = optim.Adam(mlp.parameters(), lr=flags.lr)

  pretty_print('step', 'train nll', 'train acc', 'train penalty', 'test acc')

  for step in range(flags.steps):
    for env in envs:
      logits = mlp(env['images'])
      env['nll'] = mean_nll(logits, env['labels'])
      env['acc'] = mean_accuracy(logits, env['labels'])
      env['penalty'] = penalty(logits, env['labels'])

    train_nll = torch.stack([envs[0]['nll'], envs[1]['nll']]).mean()
    train_acc = torch.stack([envs[0]['acc'], envs[1]['acc']]).mean()
    train_penalty = torch.stack([envs[0]['penalty'], envs[1]['penalty']]).mean()

    weight_norm = torch.tensor(0.).cuda()
    for w in mlp.parameters():
      weight_norm += w.norm().pow(2)

    loss = train_nll.clone()
    loss += flags.l2_regularizer_weight * weight_norm
    penalty_weight = (flags.penalty_weight 
        if step >= flags.penalty_anneal_iters else 1.0)
    loss += penalty_weight * train_penalty
    if penalty_weight > 1.0:
      # Rescale the entire loss to keep gradients in a reasonable range
      loss /= penalty_weight

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    test_acc = envs[2]['acc']
    if step % 100 == 0:
      pretty_print(
        np.int32(step),
        train_nll.detach().cpu().numpy(),
        train_acc.detach().cpu().numpy(),
        train_penalty.detach().cpu().numpy(),
        test_acc.detach().cpu().numpy()
      )

  final_train_accs.append(train_acc.detach().cpu().numpy())
  final_test_accs.append(test_acc.detach().cpu().numpy())
  print('Final train acc (mean/std across restarts so far):')
  print(np.mean(final_train_accs), np.std(final_train_accs))
  print('Final test acc (mean/std across restarts so far):')
  print(np.mean(final_test_accs), np.std(final_test_accs))
